# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import linear_model
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import utils

# %% [markdown]
# # Lasso

# %%
df = utils.load_data()
df = utils.prepare_data(df)
X_train, y_train, X_test, y_test = utils.split_data(df)

# %%
model = linear_model.LassoCV()
model.fit(X_train, y_train)

utils.evaluate_predictions(model, X_test, y_test)
# Out:
# MAE: 0.515188972215622
# MSE: 0.5423687417745324
# RMSE: 0.5423687417745324
# R2: 0.4108933266778

# %%
from sklearn.metrics import mean_absolute_error, make_scorer

label_col="acc"
X = df.drop(columns=[label_col])
y = df[label_col]
cross_val_score(model, X, y, cv=5, scoring=make_scorer(mean_absolute_error))
# Out:
# /Users/Xavier/Maitrise - Cours/Hiver 2025/Méthodes avancées en exploitation de données/code/venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.599e+00, tolerance: 1.626e-01
#   model = cd_fast.enet_coordinate_descent(
# array([0.42961386, 0.62234493, 0.4881648 , 0.48336549, 1.96415784])

# %%
# Display selected features
model.feature_names_in_[np.where(model.coef_ != 0)]
# Out:
# array(['all_pedest', 'fi', 'cli', 'cti', 'ln_pi', 'ln_fli', 'ln_cli',
#        'tot_crossw', 'tot_road_w', 'median', 'green_stra', 'half_phase',
#        'lt_protect', 'lt_restric', 'parking', 'north_veh', 'south_veh',
#        'west_ped', 'total_lane', 'commercial', 'curb_exten', 'all_red_an',
#        'ln_distdt', 'traffic_10000', 'borough_Ahuntsic-Cartierville',
#        'borough_Dorval', 'borough_Lasalle',
#        'borough_Mercier-Hochelaga-Maisonneuve', 'borough_MontrÚal-Est',
#        'borough_Outremont', 'borough_Plateau-Mont-Royal',
#        'borough_Pointe-aux-Trembles-RiviÞres-des-Prairies',
#        'borough_Saint-Laurent', 'borough_St-LÚonard',
#        'borough_Villeray-Saint-Michel-Parc-Extension'], dtype=object)

# %% [markdown]
# # Elastic Net

# %%
model = linear_model.ElasticNetCV()
model.fit(X_train, y_train)

model.score(X_test, y_test)
# Out:
# 0.09111532313849946

# %%
model.predict(X_test)
# Out:
# array([-2.90638727e-01, -4.95876983e-02, -3.60229561e-02, -1.27250792e-01,
#        -1.67629610e-01, -2.17418602e-01, -7.52956965e-03, -5.21268829e-02,
#        -7.83591332e-02,  5.97209459e-02, -1.06964090e-02, -4.22901322e-02,
#        -4.72939084e-02,  8.08829595e-02, -5.90705651e-02,  1.85869057e-01,
#        -1.18064610e-01, -1.35452307e-01,  3.35736503e-02, -2.04929073e-01,
#        -3.03961201e-02, -1.19725283e-01, -9.58765715e-02,  3.80148201e-02,
#        -1.88208555e-01,  2.54790028e-02, -7.95620169e-02, -7.96156409e-02,
#         1.90333742e-01, -4.73693025e-02, -1.29316597e-01, -1.65185767e-02,
#         2.33684206e-01, -1.74093948e-01, -6.28903217e-02, -1.03530324e-01,
#        -1.08625311e-01, -8.59235581e-02, -1.46694893e-02,  6.81917584e-02,
#        -2.29380842e-01,  6.28620244e-02,  5.26195632e-02,  2.71976161e-01,
#        -2.08811993e-02, -8.36502812e-02, -6.28666093e-02, -5.25723446e-02,
# ...
